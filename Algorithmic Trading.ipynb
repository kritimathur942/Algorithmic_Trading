# %%
a = 5
print(a)
# Out:
# 5

# %%
import yfinance as yf
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt

# %%
Apple = yf.download("AAPL", start = "2010-01-01", end = "2021-01-01") #downloads data
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
Apple
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2010-01-04    7.622500    7.660714    7.585000    7.643214    6.496294
# 2010-01-05    7.664286    7.699643    7.616071    7.656429    6.507525
# 2010-01-06    7.656429    7.686786    7.526786    7.534643    6.404015
# 2010-01-07    7.562500    7.571429    7.466071    7.520714    6.392178
# 2010-01-08    7.510714    7.571429    7.466429    7.570714    6.434674
# ...                ...         ...         ...         ...         ...
# 2020-12-24  131.320007  133.460007  131.100006  131.970001  130.025940
# 2020-12-28  133.990005  137.339996  133.509995  136.690002  134.676376
# 2020-12-29  138.050003  138.789993  134.339996  134.869995  132.883179
# 2020-12-30  135.580002  135.990005  133.399994  133.720001  131.750137
# 2020-12-31  134.080002  134.740005  131.720001  132.690002  130.735336
#
#                Volume
# Date
# 2010-01-04  493729600
# 2010-01-05  601904800
# 2010-01-06  552160000
# ...

# %%
a = [1, 2, 3,5]
a
# Out:
# [1, 2, 3, 5]

# %%
ticker = ["SPY", "AAPL", "KO"]

# %%
stocks = yf.download(ticker, start = "2010-01-01", end = "2021-01-01")
# Out:
# [*********************100%***********************]  3 of 3 completed

# %%
stocks
# Out:
#              Adj Close                              Close             \
#                   AAPL         KO         SPY        AAPL         KO
# Date
# 2010-01-04    6.487533  18.793242   87.791771    7.643214  28.520000
# 2010-01-05    6.498750  18.565899   88.024178    7.656429  28.174999
# 2010-01-06    6.395380  18.559307   88.086136    7.534643  28.165001
# 2010-01-07    6.383555  18.513186   88.457977    7.520714  28.094999
# 2010-01-08    6.425995  18.170532   88.752350    7.570714  27.575001
# ...                ...        ...         ...         ...        ...
# 2020-12-24  129.850571  49.557598  355.649170  131.970001  53.439999
# 2020-12-28  134.494781  50.225292  358.704468  136.690002  54.160000
# 2020-12-29  132.703995  50.197472  358.020142  134.869995  54.130001
# 2020-12-30  131.572464  50.484943  358.531036  133.720001  54.439999
# 2020-12-31  130.559006  50.855892  360.352661  132.690002  54.840000
#
# ...

# %%
stocks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2769 entries, 2010-01-04 to 2020-12-31
# Data columns (total 18 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   (Adj Close, AAPL)  2769 non-null   float64
#  1   (Adj Close, KO)    2769 non-null   float64
#  2   (Adj Close, SPY)   2769 non-null   float64
#  3   (Close, AAPL)      2769 non-null   float64
#  4   (Close, KO)        2769 non-null   float64
#  5   (Close, SPY)       2769 non-null   float64
#  6   (High, AAPL)       2769 non-null   float64
#  7   (High, KO)         2769 non-null   float64
#  8   (High, SPY)        2769 non-null   float64
#  9   (Low, AAPL)        2769 non-null   float64
#  10  (Low, KO)          2769 non-null   float64
#  11  (Low, SPY)         2769 non-null   float64
#  12  (Open, AAPL)       2769 non-null   float64
#  13  (Open, KO)         2769 non-null   float64
#  14  (Open, SPY)        2769 non-null   float64
# ...

# %%
stocks.to_csv("stocksYT.csv")#basically saves the data into a csv converted format

# %%
stocks = pd.read_csv("stocksYT.csv")

# %%
stocks
# Out:
#       Unnamed: 0           Adj Close         Adj Close.1        Adj Close.2  \
# 0            NaN                AAPL                  KO                SPY
# 1           Date                 NaN                 NaN                NaN
# 2     2010-01-04   6.487532615661621  18.793241500854492   87.7917709350586
# 3     2010-01-05   6.498749732971191  18.565898895263672  88.02417755126953
# 4     2010-01-06   6.395379543304443  18.559307098388672  88.08613586425781
# ...          ...                 ...                 ...                ...
# 2766  2020-12-24  129.85057067871094   49.55759811401367   355.649169921875
# 2767  2020-12-28  134.49478149414062   50.22529220581055  358.7044677734375
# 2768  2020-12-29  132.70399475097656  50.197471618652344  358.0201416015625
# 2769  2020-12-30   131.5724639892578   50.48494338989258  358.5310363769531
# 2770  2020-12-31   130.5590057373047  50.855892181396484  360.3526611328125
#
# ...

# %%
stocks = pd.read_csv("stocksYT.csv", header=[0,1])
stocks
# Out:
#      Unnamed: 0_level_0   Adj Close                              Close  \
#      Unnamed: 0_level_1        AAPL         KO         SPY        AAPL
# 0                  Date         NaN        NaN         NaN         NaN
# 1            2010-01-04    6.487533  18.793242   87.791771    7.643214
# 2            2010-01-05    6.498750  18.565899   88.024178    7.656429
# 3            2010-01-06    6.395380  18.559307   88.086136    7.534643
# 4            2010-01-07    6.383555  18.513186   88.457977    7.520714
# ...                 ...         ...        ...         ...         ...
# 2765         2020-12-24  129.850571  49.557598  355.649170  131.970001
# 2766         2020-12-28  134.494781  50.225292  358.704468  136.690002
# 2767         2020-12-29  132.703995  50.197472  358.020142  134.869995
# 2768         2020-12-30  131.572464  50.484943  358.531036  133.720001
# 2769         2020-12-31  130.559006  50.855892  360.352661  132.690002
#
# ...

# %%
stocks = pd.read_csv("stocksYT.csv", header=[0,1], index_col = [0]) #removed the indexing 
stocks
# Out:
#              Adj Close                              Close             \
#                   AAPL         KO         SPY        AAPL         KO
# Date
# 2010-01-04    6.487533  18.793242   87.791771    7.643214  28.520000
# 2010-01-05    6.498750  18.565899   88.024178    7.656429  28.174999
# 2010-01-06    6.395380  18.559307   88.086136    7.534643  28.165001
# 2010-01-07    6.383555  18.513186   88.457977    7.520714  28.094999
# 2010-01-08    6.425995  18.170532   88.752350    7.570714  27.575001
# ...                ...        ...         ...         ...        ...
# 2020-12-24  129.850571  49.557598  355.649170  131.970001  53.439999
# 2020-12-28  134.494781  50.225292  358.704468  136.690002  54.160000
# 2020-12-29  132.703995  50.197472  358.020142  134.869995  54.130001
# 2020-12-30  131.572464  50.484943  358.531036  133.720001  54.439999
# 2020-12-31  130.559006  50.855892  360.352661  132.690002  54.840000
#
# ...

# %%
stocks = pd.read_csv("stocksYT.csv", header=[0,1], index_col = [0], parse_dates=[0]) #forms a list of date n times and represents it as a columns 
stocks
# Out:
#              Adj Close                              Close             \
#                   AAPL         KO         SPY        AAPL         KO
# Date
# 2010-01-04    6.487533  18.793242   87.791771    7.643214  28.520000
# 2010-01-05    6.498750  18.565899   88.024178    7.656429  28.174999
# 2010-01-06    6.395380  18.559307   88.086136    7.534643  28.165001
# 2010-01-07    6.383555  18.513186   88.457977    7.520714  28.094999
# 2010-01-08    6.425995  18.170532   88.752350    7.570714  27.575001
# ...                ...        ...         ...         ...        ...
# 2020-12-24  129.850571  49.557598  355.649170  131.970001  53.439999
# 2020-12-28  134.494781  50.225292  358.704468  136.690002  54.160000
# 2020-12-29  132.703995  50.197472  358.020142  134.869995  54.130001
# 2020-12-30  131.572464  50.484943  358.531036  133.720001  54.439999
# 2020-12-31  130.559006  50.855892  360.352661  132.690002  54.840000
#
# ...

# %%
stocks.columns #this is in multiindex
# Out:
# MultiIndex([('Adj Close', 'AAPL'),
#             ('Adj Close',   'KO'),
#             ('Adj Close',  'SPY'),
#             (    'Close', 'AAPL'),
#             (    'Close',   'KO'),
#             (    'Close',  'SPY'),
#             (     'High', 'AAPL'),
#             (     'High',   'KO'),
#             (     'High',  'SPY'),
#             (      'Low', 'AAPL'),
#             (      'Low',   'KO'),
#             (      'Low',  'SPY'),
#             (     'Open', 'AAPL'),
#             (     'Open',   'KO'),
#             (     'Open',  'SPY'),
#             (   'Volume', 'AAPL'),
#             (   'Volume',   'KO'),
#             (   'Volume',  'SPY')],
#            )

# %%
#converting into one tuple 
stocks.columns = stocks.columns.to_flat_index() #converted into single index

# %%
stocks.columns
# Out:
# Index([('Adj Close', 'AAPL'),   ('Adj Close', 'KO'),  ('Adj Close', 'SPY'),
#            ('Close', 'AAPL'),       ('Close', 'KO'),      ('Close', 'SPY'),
#             ('High', 'AAPL'),        ('High', 'KO'),       ('High', 'SPY'),
#              ('Low', 'AAPL'),         ('Low', 'KO'),        ('Low', 'SPY'),
#             ('Open', 'AAPL'),        ('Open', 'KO'),       ('Open', 'SPY'),
#           ('Volume', 'AAPL'),      ('Volume', 'KO'),     ('Volume', 'SPY')],
#       dtype='object')

# %%
stocks #format adjusted accordingly
# Out:
#             (Adj Close, AAPL)  (Adj Close, KO)  (Adj Close, SPY)  \
# Date
# 2010-01-04           6.487533        18.793242         87.791771
# 2010-01-05           6.498750        18.565899         88.024178
# 2010-01-06           6.395380        18.559307         88.086136
# 2010-01-07           6.383555        18.513186         88.457977
# 2010-01-08           6.425995        18.170532         88.752350
# ...                       ...              ...               ...
# 2020-12-24         129.850571        49.557598        355.649170
# 2020-12-28         134.494781        50.225292        358.704468
# 2020-12-29         132.703995        50.197472        358.020142
# 2020-12-30         131.572464        50.484943        358.531036
# 2020-12-31         130.559006        50.855892        360.352661
#
#             (Close, AAPL)  (Close, KO)  (Close, SPY)  (High, AAPL)  \
# Date
# 2010-01-04       7.643214    28.520000    113.330002      7.660714
# ...

# %%
stocks.columns = pd.MultiIndex.from_tuples(stocks.columns)

# %%
stocks
# Out:
#              Adj Close                              Close             \
#                   AAPL         KO         SPY        AAPL         KO
# Date
# 2010-01-04    6.487533  18.793242   87.791771    7.643214  28.520000
# 2010-01-05    6.498750  18.565899   88.024178    7.656429  28.174999
# 2010-01-06    6.395380  18.559307   88.086136    7.534643  28.165001
# 2010-01-07    6.383555  18.513186   88.457977    7.520714  28.094999
# 2010-01-08    6.425995  18.170532   88.752350    7.570714  27.575001
# ...                ...        ...         ...         ...        ...
# 2020-12-24  129.850571  49.557598  355.649170  131.970001  53.439999
# 2020-12-28  134.494781  50.225292  358.704468  136.690002  54.160000
# 2020-12-29  132.703995  50.197472  358.020142  134.869995  54.130001
# 2020-12-30  131.572464  50.484943  358.531036  133.720001  54.439999
# 2020-12-31  130.559006  50.855892  360.352661  132.690002  54.840000
#
# ...

# %%
stocks.columns
# Out:
# MultiIndex([('Adj Close', 'AAPL'),
#             ('Adj Close',   'KO'),
#             ('Adj Close',  'SPY'),
#             (    'Close', 'AAPL'),
#             (    'Close',   'KO'),
#             (    'Close',  'SPY'),
#             (     'High', 'AAPL'),
#             (     'High',   'KO'),
#             (     'High',  'SPY'),
#             (      'Low', 'AAPL'),
#             (      'Low',   'KO'),
#             (      'Low',  'SPY'),
#             (     'Open', 'AAPL'),
#             (     'Open',   'KO'),
#             (     'Open',  'SPY'),
#             (   'Volume', 'AAPL'),
#             (   'Volume',   'KO'),
#             (   'Volume',  'SPY')],
#            )

# %%
#describe function 
stocks.describe()
# Out:
#          Adj Close                                  Close               \
#               AAPL           KO          SPY         AAPL           KO
# count  2769.000000  2769.000000  2769.000000  2769.000000  2769.000000
# mean     31.604148    32.722795   183.435246    33.777537    41.320121
# std      24.647222     8.314333    70.233047    24.572747     6.808527
# min       5.821835    16.635143    79.874069     6.858929    25.014999
# 25%      15.221347    27.030163   115.753868    17.484285    37.660000
# 50%      24.581585    32.275936   177.317841    26.987499    41.759998
# 75%      40.985550    38.229053   243.770508    43.007500    45.549999
# max     134.494781    53.916512   360.352661   136.690002    60.130001
#
#                            High                                    Low  \
#                SPY         AAPL           KO          SPY         AAPL
# count  2769.000000  2769.000000  2769.000000  2769.000000  2769.000000
# ...

# %%
stocks.loc[:,"Close"]
# Out:
#                   AAPL         KO         SPY
# Date
# 2010-01-04    7.643214  28.520000  113.330002
# 2010-01-05    7.656429  28.174999  113.629997
# 2010-01-06    7.534643  28.165001  113.709999
# 2010-01-07    7.520714  28.094999  114.190002
# 2010-01-08    7.570714  27.575001  114.570000
# ...                ...        ...         ...
# 2020-12-24  131.970001  53.439999  369.000000
# 2020-12-28  136.690002  54.160000  372.170013
# 2020-12-29  134.869995  54.130001  371.459991
# 2020-12-30  133.720001  54.439999  371.989990
# 2020-12-31  132.690002  54.840000  373.880005
#
# [2769 rows x 3 columns]

# %%
close = stocks.loc[:,"Close"].copy()
close
# Out:
#                   AAPL         KO         SPY
# Date
# 2010-01-04    7.643214  28.520000  113.330002
# 2010-01-05    7.656429  28.174999  113.629997
# 2010-01-06    7.534643  28.165001  113.709999
# 2010-01-07    7.520714  28.094999  114.190002
# 2010-01-08    7.570714  27.575001  114.570000
# ...                ...        ...         ...
# 2020-12-24  131.970001  53.439999  369.000000
# 2020-12-28  136.690002  54.160000  372.170013
# 2020-12-29  134.869995  54.130001  371.459991
# 2020-12-30  133.720001  54.439999  371.989990
# 2020-12-31  132.690002  54.840000  373.880005
#
# [2769 rows x 3 columns]

# %% [markdown]
# # Data Visualisation and graphs

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
# !pip install seaborn
import seaborn as sns
sns.set(style="whitegrid")  # Replace "whitegrid" with the specific style you want to use

# %%
close.plot(figsize=(15,8), fontsize=12)
# Out:
# <Axes: xlabel='Date'>

# %%
close.iloc[0,0]
# Out:
# 7.643214225769043

# %%
close.AAPL
# Out:
# Date
# 2010-01-04      7.643214
# 2010-01-05      7.656429
# 2010-01-06      7.534643
# 2010-01-07      7.520714
# 2010-01-08      7.570714
#                  ...
# 2020-12-24    131.970001
# 2020-12-28    136.690002
# 2020-12-29    134.869995
# 2020-12-30    133.720001
# 2020-12-31    132.690002
# Name: AAPL, Length: 2769, dtype: float64

# %%
close.AAPL.div(close.iloc[0,0])
# Out:
# Date
# 2010-01-04     1.000000
# 2010-01-05     1.001729
# 2010-01-06     0.985795
# 2010-01-07     0.983973
# 2010-01-08     0.990514
#                 ...
# 2020-12-24    17.266296
# 2020-12-28    17.883838
# 2020-12-29    17.645717
# 2020-12-30    17.495258
# 2020-12-31    17.360498
# Name: AAPL, Length: 2769, dtype: float64

# %%
close.AAPL.div(close.iloc[0,0]).mul(100)#multiply by 100 so it smoothens the function
# Out:
# Date
# 2010-01-04     100.000000
# 2010-01-05     100.172893
# 2010-01-06      98.579511
# 2010-01-07      98.397266
# 2010-01-08      99.051443
#                  ...
# 2020-12-24    1726.629626
# 2020-12-28    1788.383766
# 2020-12-29    1764.571699
# 2020-12-30    1749.525753
# 2020-12-31    1736.049763
# Name: AAPL, Length: 2769, dtype: float64

# %%
close.iloc[0]
# Out:
# AAPL      7.643214
# KO       28.520000
# SPY     113.330002
# Name: 2010-01-04 00:00:00, dtype: float64

# %%
close.div(close.iloc[0]).mul(100)
# Out:
#                    AAPL          KO         SPY
# Date
# 2010-01-04   100.000000  100.000000  100.000000
# 2010-01-05   100.172893   98.790318  100.264710
# 2010-01-06    98.579511   98.755261  100.335302
# 2010-01-07    98.397266   98.509814  100.758846
# 2010-01-08    99.051443   96.686537  101.094148
# ...                 ...         ...         ...
# 2020-12-24  1726.629626  187.377271  325.597806
# 2020-12-28  1788.383766  189.901820  328.394959
# 2020-12-29  1764.571699  189.796635  327.768451
# 2020-12-30  1749.525753  190.883583  328.236111
# 2020-12-31  1736.049763  192.286112  329.903820
#
# [2769 rows x 3 columns]

# %%
normclose = close.div(close.iloc[0]).mul(100)

# %%
normclose.plot(figsize=(15,8), fontsize=12)
plt.legend(fontsize = 12)
plt.show()

# %% [markdown]
# # Making changes and creating data

# %%
aapl = close.AAPL.copy().to_frame()

# %%
aapl
# Out:
#                   AAPL
# Date
# 2010-01-04    7.643214
# 2010-01-05    7.656429
# 2010-01-06    7.534643
# 2010-01-07    7.520714
# 2010-01-08    7.570714
# ...                ...
# 2020-12-24  131.970001
# 2020-12-28  136.690002
# 2020-12-29  134.869995
# 2020-12-30  133.720001
# 2020-12-31  132.690002
#
# [2769 rows x 1 columns]

# %%
#shift function for increase or decrease in data 
aapl.shift(periods=1)
# Out:
#                   AAPL
# Date
# 2010-01-04         NaN
# 2010-01-05    7.643214
# 2010-01-06    7.656429
# 2010-01-07    7.534643
# 2010-01-08    7.520714
# ...                ...
# 2020-12-24  130.960007
# 2020-12-28  131.970001
# 2020-12-29  136.690002
# 2020-12-30  134.869995
# 2020-12-31  133.720001
#
# [2769 rows x 1 columns]

# %%
aapl["lag1"] = aapl.shift(periods=1) #new column will be created

# %%
aapl
# Out:
#                   AAPL        lag1
# Date
# 2010-01-04    7.643214         NaN
# 2010-01-05    7.656429    7.643214
# 2010-01-06    7.534643    7.656429
# 2010-01-07    7.520714    7.534643
# 2010-01-08    7.570714    7.520714
# ...                ...         ...
# 2020-12-24  131.970001  130.960007
# 2020-12-28  136.690002  131.970001
# 2020-12-29  134.869995  136.690002
# 2020-12-30  133.720001  134.869995
# 2020-12-31  132.690002  133.720001
#
# [2769 rows x 2 columns]

# %%
aapl.AAPL.sub(aapl.lag1) #subtract function subs the both cols
# Out:
# Date
# 2010-01-04         NaN
# 2010-01-05    0.013215
# 2010-01-06   -0.121786
# 2010-01-07   -0.013929
# 2010-01-08    0.050000
#                 ...
# 2020-12-24    1.009995
# 2020-12-28    4.720001
# 2020-12-29   -1.820007
# 2020-12-30   -1.149994
# 2020-12-31   -1.029999
# Length: 2769, dtype: float64

# %%
aapl["Diff"] = aapl.AAPL.sub(aapl.lag1)

# %%
aapl
# Out:
#                   AAPL        lag1      Diff
# Date
# 2010-01-04    7.643214         NaN       NaN
# 2010-01-05    7.656429    7.643214  0.013215
# 2010-01-06    7.534643    7.656429 -0.121786
# 2010-01-07    7.520714    7.534643 -0.013929
# 2010-01-08    7.570714    7.520714  0.050000
# ...                ...         ...       ...
# 2020-12-24  131.970001  130.960007  1.009995
# 2020-12-28  136.690002  131.970001  4.720001
# 2020-12-29  134.869995  136.690002 -1.820007
# 2020-12-30  133.720001  134.869995 -1.149994
# 2020-12-31  132.690002  133.720001 -1.029999
#
# [2769 rows x 3 columns]

# %%
#now we divide in similar way 
aapl["%change"]=aapl.AAPL.div(aapl.lag1).sub(1).mul(100)

# %%
aapl
# Out:
#                   AAPL        lag1      Diff   %change  %change2
# Date
# 2010-01-04    7.643214         NaN       NaN       NaN       NaN
# 2010-01-05    7.656429    7.643214  0.013215  0.172893  0.172893
# 2010-01-06    7.534643    7.656429 -0.121786 -1.590632 -1.590632
# 2010-01-07    7.520714    7.534643 -0.013929 -0.184871 -0.184871
# 2010-01-08    7.570714    7.520714  0.050000  0.664833  0.664833
# ...                ...         ...       ...       ...       ...
# 2020-12-24  131.970001  130.960007  1.009995  0.771224  0.771224
# 2020-12-28  136.690002  131.970001  4.720001  3.576571  3.576571
# 2020-12-29  134.869995  136.690002 -1.820007 -1.331485 -1.331485
# 2020-12-30  133.720001  134.869995 -1.149994 -0.852668 -0.852668
# 2020-12-31  132.690002  133.720001 -1.029999 -0.770265 -0.770265
#
# [2769 rows x 5 columns]

# %%
aapl["Diff2"]= aapl.AAPL.diff(periods=1)
aapl
# Out:
#                   AAPL        lag1      Diff   %change  %change2     Diff2
# Date
# 2010-01-04    7.643214         NaN       NaN       NaN       NaN       NaN
# 2010-01-05    7.656429    7.643214  0.013215  0.172893  0.172893  0.013215
# 2010-01-06    7.534643    7.656429 -0.121786 -1.590632 -1.590632 -0.121786
# 2010-01-07    7.520714    7.534643 -0.013929 -0.184871 -0.184871 -0.013929
# 2010-01-08    7.570714    7.520714  0.050000  0.664833  0.664833  0.050000
# ...                ...         ...       ...       ...       ...       ...
# 2020-12-24  131.970001  130.960007  1.009995  0.771224  0.771224  1.009995
# 2020-12-28  136.690002  131.970001  4.720001  3.576571  3.576571  4.720001
# 2020-12-29  134.869995  136.690002 -1.820007 -1.331485 -1.331485 -1.820007
# 2020-12-30  133.720001  134.869995 -1.149994 -0.852668 -0.852668 -1.149994
# 2020-12-31  132.690002  133.720001 -1.029999 -0.770265 -0.770265 -1.029999
#
# [2769 rows x 6 columns]

# %%
aapl["%change2"]=aapl.AAPL.pct_change(periods=1).mul(100)
aapl
# Out:
#                   AAPL        lag1      Diff   %change  %change2     Diff2
# Date
# 2010-01-04    7.643214         NaN       NaN       NaN       NaN       NaN
# 2010-01-05    7.656429    7.643214  0.013215  0.172893  0.172893  0.013215
# 2010-01-06    7.534643    7.656429 -0.121786 -1.590632 -1.590632 -0.121786
# 2010-01-07    7.520714    7.534643 -0.013929 -0.184871 -0.184871 -0.013929
# 2010-01-08    7.570714    7.520714  0.050000  0.664833  0.664833  0.050000
# ...                ...         ...       ...       ...       ...       ...
# 2020-12-24  131.970001  130.960007  1.009995  0.771224  0.771224  1.009995
# 2020-12-28  136.690002  131.970001  4.720001  3.576571  3.576571  4.720001
# 2020-12-29  134.869995  136.690002 -1.820007 -1.331485 -1.331485 -1.820007
# 2020-12-30  133.720001  134.869995 -1.149994 -0.852668 -0.852668 -1.149994
# 2020-12-31  132.690002  133.720001 -1.029999 -0.770265 -0.770265 -1.029999
#
# [2769 rows x 6 columns]

# %%
del aapl["Diff2"]
aapl
# Out:
#                   AAPL        lag1      Diff   %change  %change2
# Date
# 2010-01-04    7.643214         NaN       NaN       NaN       NaN
# 2010-01-05    7.656429    7.643214  0.013215  0.172893  0.172893
# 2010-01-06    7.534643    7.656429 -0.121786 -1.590632 -1.590632
# 2010-01-07    7.520714    7.534643 -0.013929 -0.184871 -0.184871
# 2010-01-08    7.570714    7.520714  0.050000  0.664833  0.664833
# ...                ...         ...       ...       ...       ...
# 2020-12-24  131.970001  130.960007  1.009995  0.771224  0.771224
# 2020-12-28  136.690002  131.970001  4.720001  3.576571  3.576571
# 2020-12-29  134.869995  136.690002 -1.820007 -1.331485 -1.331485
# 2020-12-30  133.720001  134.869995 -1.149994 -0.852668 -0.852668
# 2020-12-31  132.690002  133.720001 -1.029999 -0.770265 -0.770265
#
# [2769 rows x 5 columns]

# %%
del aapl["lag1"]
aapl
# Out:
#                   AAPL      Diff   %change  %change2
# Date
# 2010-01-04    7.643214       NaN       NaN       NaN
# 2010-01-05    7.656429  0.013215  0.172893  0.172893
# 2010-01-06    7.534643 -0.121786 -1.590632 -1.590632
# 2010-01-07    7.520714 -0.013929 -0.184871 -0.184871
# 2010-01-08    7.570714  0.050000  0.664833  0.664833
# ...                ...       ...       ...       ...
# 2020-12-24  131.970001  1.009995  0.771224  0.771224
# 2020-12-28  136.690002  4.720001  3.576571  3.576571
# 2020-12-29  134.869995 -1.820007 -1.331485 -1.331485
# 2020-12-30  133.720001 -1.149994 -0.852668 -0.852668
# 2020-12-31  132.690002 -1.029999 -0.770265 -0.770265
#
# [2769 rows x 4 columns]

# %%
del aapl["Diff"]
aapl
# Out:
#                   AAPL   %change  %change2
# Date
# 2010-01-04    7.643214       NaN       NaN
# 2010-01-05    7.656429  0.172893  0.172893
# 2010-01-06    7.534643 -1.590632 -1.590632
# 2010-01-07    7.520714 -0.184871 -0.184871
# 2010-01-08    7.570714  0.664833  0.664833
# ...                ...       ...       ...
# 2020-12-24  131.970001  0.771224  0.771224
# 2020-12-28  136.690002  3.576571  3.576571
# 2020-12-29  134.869995 -1.331485 -1.331485
# 2020-12-30  133.720001 -0.852668 -0.852668
# 2020-12-31  132.690002 -0.770265 -0.770265
#
# [2769 rows x 3 columns]

# %%
del aapl["%change"]
aapl
# Out:
#                   AAPL  %change2
# Date
# 2010-01-04    7.643214       NaN
# 2010-01-05    7.656429  0.172893
# 2010-01-06    7.534643 -1.590632
# 2010-01-07    7.520714 -0.184871
# 2010-01-08    7.570714  0.664833
# ...                ...       ...
# 2020-12-24  131.970001  0.771224
# 2020-12-28  136.690002  3.576571
# 2020-12-29  134.869995 -1.331485
# 2020-12-30  133.720001 -0.852668
# 2020-12-31  132.690002 -0.770265
#
# [2769 rows x 2 columns]

# %%
#renaming cols 
aapl.rename(columns = {'%change2': 'Change'}, inplace = True)

# %%
aapl
# Out:
#                   AAPL    Change
# Date
# 2010-01-04    7.643214       NaN
# 2010-01-05    7.656429  0.172893
# 2010-01-06    7.534643 -1.590632
# 2010-01-07    7.520714 -0.184871
# 2010-01-08    7.570714  0.664833
# ...                ...       ...
# 2020-12-24  131.970001  0.771224
# 2020-12-28  136.690002  3.576571
# 2020-12-29  134.869995 -1.331485
# 2020-12-30  133.720001 -0.852668
# 2020-12-31  132.690002 -0.770265
#
# [2769 rows x 2 columns]

# %% [markdown]
# # Resampling

# %%
#resampling Data 
aapl.AAPL.resample("M").last()
# Out:
# Date
# 2010-01-31      6.859286
# 2010-02-28      7.307857
# 2010-03-31      8.392857
# 2010-04-30      9.324643
# 2010-05-31      9.174286
#                  ...
# 2020-08-31    129.039993
# 2020-09-30    115.809998
# 2020-10-31    108.860001
# 2020-11-30    119.050003
# 2020-12-31    132.690002
# Freq: M, Name: AAPL, Length: 132, dtype: float64

# %%
aapl.AAPL.resample("BM").last().pct_change(periods=1).mul(100)#monthly frame for business months
# Out:
# Date
# 2010-01-29          NaN
# 2010-02-26     6.539620
# 2010-03-31    14.847028
# 2010-04-30    11.102138
# 2010-05-31    -1.612472
#                 ...
# 2020-08-31    21.437974
# 2020-09-30   -10.252632
# 2020-10-30    -6.001206
# 2020-11-30     9.360649
# 2020-12-31    11.457370
# Freq: BM, Name: AAPL, Length: 132, dtype: float64

# %%
#calculating the mean return and standard deviation 
del aapl["Change"]

# %%
aapl
# Out:
#                   AAPL
# Date
# 2010-01-04    7.643214
# 2010-01-05    7.656429
# 2010-01-06    7.534643
# 2010-01-07    7.520714
# 2010-01-08    7.570714
# ...                ...
# 2020-12-24  131.970001
# 2020-12-28  136.690002
# 2020-12-29  134.869995
# 2020-12-30  133.720001
# 2020-12-31  132.690002
#
# [2769 rows x 1 columns]

# %%
ret = aapl.pct_change()

# %%
ret
# Out:
#                 AAPL
# Date
# 2010-01-04       NaN
# 2010-01-05  0.001729
# 2010-01-06 -0.015906
# 2010-01-07 -0.001849
# 2010-01-08  0.006648
# ...              ...
# 2020-12-24  0.007712
# 2020-12-28  0.035766
# 2020-12-29 -0.013315
# 2020-12-30 -0.008527
# 2020-12-31 -0.007703
#
# [2769 rows x 1 columns]

# %%
ret = aapl.pct_change().dropna() #takes out na whichever row has it it makes data look v clean
ret
# Out:
#                 AAPL
# Date
# 2010-01-05  0.001729
# 2010-01-06 -0.015906
# 2010-01-07 -0.001849
# 2010-01-08  0.006648
# 2010-01-11 -0.008821
# ...              ...
# 2020-12-24  0.007712
# 2020-12-28  0.035766
# 2020-12-29 -0.013315
# 2020-12-30 -0.008527
# 2020-12-31 -0.007703
#
# [2768 rows x 1 columns]

# %%
ret.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2768 entries, 2010-01-05 to 2020-12-31
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   AAPL    2768 non-null   float64
# dtypes: float64(1)
# memory usage: 43.2 KB

# %%
ret.plot(kind="hist", figsize=(12,8), bins=100)
plt.show()#majority of time trading range is between this range 
#we can multiply it by 100

# %%
#calculating the mean return 
ret.mean().mul(100)
# Out:
# AAPL    0.119101
# dtype: float64

# %%
daily_mean_ret= ret.mean()
daily_mean_ret
# Out:
# AAPL    0.001191
# dtype: float64

# %%
var_daily = ret.var()
var_daily
# Out:
# AAPL    0.000318
# dtype: float64

# %%
#standard deviation 
std_daily = np.sqrt(var_daily)
std_daily
# Out:
# AAPL    0.017843
# dtype: float64

# %%
annual_mean_ret = daily_mean_ret*252
annual_mean_ret
# Out:
# AAPL    0.300134
# dtype: float64

# %%
annual_var_return = var_daily*252 
#252 because those are the working days that we have 
annual_var_return
# Out:
# AAPL    0.080226
# dtype: float64

# %%
annual_std_return =np.sqrt(annual_var_return)
annual_std_return
# Out:
# AAPL    0.283242
# dtype: float64

# %%
ret.std()*np.sqrt(252)
# Out:
# AAPL    0.283242
# dtype: float64

# %%
ticker = ["SPY", "AAPL", "KO", "IBM", "DIS", "MSFT"]
#more data for comarison learn

# %%
stocks = yf.download(ticker, start = "2010-01-01", end="2021-01-01")
# Out:
# [*********************100%***********************]  6 of 6 completed

# %%
close = stocks.loc[:,"Close"].copy()

# %%
normclose = close.div(close.iloc[0]).mul(100)

# %%
normclose.plot(figsize=(15,8), fontsize=12)
plt.legend(fontsize = 12)
plt.show()

# %%
ret=close.pct_change().dropna()
ret.head()
# Out:
#                 AAPL       DIS       IBM        KO      MSFT       SPY
# Date
# 2010-01-05  0.001729 -0.002495 -0.012080 -0.012097  0.000323  0.002647
# 2010-01-06 -0.015906 -0.005314 -0.006496 -0.000355 -0.006137  0.000704
# 2010-01-07 -0.001849  0.000314 -0.003462 -0.002485 -0.010400  0.004221
# 2010-01-08  0.006648  0.001571  0.010035 -0.018509  0.006897  0.003328
# 2010-01-11 -0.008821 -0.016311 -0.010470  0.020308 -0.012720  0.001397

# %%
ret.describe()
# Out:
#               AAPL          DIS          IBM           KO         MSFT  \
# count  2768.000000  2768.000000  2768.000000  2768.000000  2768.000000
# mean      0.001191     0.000749     0.000082     0.000298     0.000841
# std       0.017843     0.015717     0.014132     0.011088     0.016012
# min      -0.128647    -0.129846    -0.128507    -0.096725    -0.147390
# 25%      -0.007123    -0.006210    -0.006321    -0.004698    -0.006939
# 50%       0.000903     0.000629     0.000287     0.000438     0.000654
# 75%       0.010379     0.007901     0.006743     0.005706     0.008636
# max       0.119808     0.144123     0.113010     0.064796     0.142169
#
#                SPY
# count  2768.000000
# mean      0.000491
# std       0.010909
# min      -0.109424
# 25%      -0.003532
# 50%       0.000637
# 75%       0.005421
# max       0.090603

# %%
#transposing cols 
ret.describe().T
# Out:
#        count      mean       std       min       25%       50%       75%  \
# AAPL  2768.0  0.001191  0.017843 -0.128647 -0.007123  0.000903  0.010379
# DIS   2768.0  0.000749  0.015717 -0.129846 -0.006210  0.000629  0.007901
# IBM   2768.0  0.000082  0.014132 -0.128507 -0.006321  0.000287  0.006743
# KO    2768.0  0.000298  0.011088 -0.096725 -0.004698  0.000438  0.005706
# MSFT  2768.0  0.000841  0.016012 -0.147390 -0.006939  0.000654  0.008636
# SPY   2768.0  0.000491  0.010909 -0.109424 -0.003532  0.000637  0.005421
#
#            max
# AAPL  0.119808
# DIS   0.144123
# IBM   0.113010
# KO    0.064796
# MSFT  0.142169
# SPY   0.090603

# %%
ret.describe().T.loc[:, ["mean", "std"]]
# Out:
#           mean       std
# AAPL  0.001191  0.017843
# DIS   0.000749  0.015717
# IBM   0.000082  0.014132
# KO    0.000298  0.011088
# MSFT  0.000841  0.016012
# SPY   0.000491  0.010909

# %%
summary = ret.describe().T.loc[:, ["mean", "std"]]
summary
# Out:
#           mean       std
# AAPL  0.001191  0.017843
# DIS   0.000749  0.015717
# IBM   0.000082  0.014132
# KO    0.000298  0.011088
# MSFT  0.000841  0.016012
# SPY   0.000491  0.010909

# %%
summary["mean"]=summary["mean"]*252
summary["std"]=summary["std"]*np.sqrt(252)
summary
# Out:
#           mean       std
# AAPL  0.300134  0.283242
# DIS   0.188696  0.249504
# IBM   0.020648  0.224345
# KO    0.075091  0.176009
# MSFT  0.211915  0.254185
# SPY   0.123754  0.173170

# %%
summary.plot.scatter(x="std", y="mean", figsize=(12,8), s=50, fontsize=15)
for i in summary.index:
    plt.annotate(i, xy=(summary.loc[i, "std"]+0.002, summary.loc[i, "mean"]+0.002), size=15)
    #annotate function helps in plotting the values 
plt.xlabel("Annual risk(std)", fontsize = 15)
plt.ylabel("Annual return", fontsize = 15)
plt.title("Risk/return", fontsize = 25)
plt.show()#0.002 is just graph distance n size

# %% [markdown]
# # Correlation and Covariance

# %%
ret
# Out:
#                 AAPL       DIS       IBM        KO      MSFT       SPY
# Date
# 2010-01-05  0.001729 -0.002495 -0.012080 -0.012097  0.000323  0.002647
# 2010-01-06 -0.015906 -0.005314 -0.006496 -0.000355 -0.006137  0.000704
# 2010-01-07 -0.001849  0.000314 -0.003462 -0.002485 -0.010400  0.004221
# 2010-01-08  0.006648  0.001571  0.010035 -0.018509  0.006897  0.003328
# 2010-01-11 -0.008821 -0.016311 -0.010470  0.020308 -0.012720  0.001397
# ...              ...       ...       ...       ...       ...       ...
# 2020-12-24  0.007712  0.001037  0.006376  0.006782  0.007827  0.003890
# 2020-12-28  0.035766  0.029529  0.001043  0.013473  0.009921  0.008591
# 2020-12-29 -0.013315 -0.008722 -0.008172 -0.000554 -0.003601 -0.001908
# 2020-12-30 -0.008527  0.021827  0.004362  0.005727 -0.011019  0.001427
# 2020-12-31 -0.007703  0.000055  0.012385  0.007348  0.003338  0.005081
#
# [2768 rows x 6 columns]

# %%
ret.cov()#gives covariance
# Out:
#           AAPL       DIS       IBM        KO      MSFT       SPY
# AAPL  0.000318  0.000115  0.000110  0.000067  0.000158  0.000128
# DIS   0.000115  0.000247  0.000111  0.000085  0.000121  0.000121
# IBM   0.000110  0.000111  0.000200  0.000079  0.000121  0.000108
# KO    0.000067  0.000085  0.000079  0.000123  0.000076  0.000077
# MSFT  0.000158  0.000121  0.000121  0.000076  0.000256  0.000130
# SPY   0.000128  0.000121  0.000108  0.000077  0.000130  0.000119

# %%
ret.corr()
# Out:
#           AAPL       DIS       IBM        KO      MSFT       SPY
# AAPL  1.000000  0.408513  0.436100  0.339213  0.554051  0.659557
# DIS   0.408513  1.000000  0.497775  0.486514  0.480457  0.706726
# IBM   0.436100  0.497775  1.000000  0.502436  0.533130  0.703342
# KO    0.339213  0.486514  0.502436  1.000000  0.429749  0.639324
# MSFT  0.554051  0.480457  0.533130  0.429749  1.000000  0.744601
# SPY   0.659557  0.706726  0.703342  0.639324  0.744601  1.000000

# %%
import seaborn as sns

# %%
plt.figure(figsize=(12,8))
sns.set(font_scale=1.4)
sns.heatmap(ret.corr(),cmap="Reds",annot=True,annot_kws={"size":15},vmax=0.6)
plt.show()#spy jsut has high correlation with market #apple and cocacola have the least correlation and thats the kind we want to see 
#these are highly correlated stocks but usually we need low
#spy just has high correlation

# %% [markdown]
# Till now we've downloaded 6 random stocks from yahoo finance and then calculated the risk and reward potential and compared covariance and correlation which leads us to evaluation of the best stocks to invest in long term amongst these 6

# %% [markdown]
# # Simple returns and log returns

# %%
df = pd.DataFrame(index=[2016,2017,2018], data=[100,50,95], columns=["price"])

# %%
df
# Out:
#       price
# 2016    100
# 2017     50
# 2018     95

# %%
simplereturns=df.pct_change().dropna()
simplereturns
# Out:
#       price
# 2017   -0.5
# 2018    0.9

# %%
simplereturns.mean()#simple return gets calculated from previous not from 
#first so actual returns if it were 0.2 wouldve been 144 but its not its 95
#so that is why we calculate log returns
#mean returns are misleading
# Out:
# price    0.2
# dtype: float64

# %%
logreturns=np.log(df/df.shift(1)).dropna()
logreturns
# Out:
#          price
# 2017 -0.693147
# 2018  0.641854

# %%
logreturns.mean()
# Out:
# price   -0.025647
# dtype: float64

# %%
100*np.exp(logreturns.mean()*2)#this gives us the ending price 
#more accurate
# Out:
# price    95.0
# dtype: float64

# %%
SPY = yf.download("SPY") #downloads data #all data available
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
spy=SPY.Close.to_frame()#gives data in dataframe format

# %%
spy
# Out:
#                  Close
# Date
# 1993-01-29   43.937500
# 1993-02-01   44.250000
# 1993-02-02   44.343750
# 1993-02-03   44.812500
# 1993-02-04   45.000000
# ...                ...
# 2023-08-08  448.750000
# 2023-08-09  445.750000
# 2023-08-10  445.910004
# 2023-08-11  445.649994
# 2023-08-14  448.109985
#
# [7690 rows x 1 columns]

# %%
spy.plot(figsize=(12,8), fontsize=15)
plt.legend(loc="upper left", fontsize=15)
plt.show()

# %%
spy_roll=spy.rolling(window=10)

# %%
spy_roll=spy_roll.mean()

# %%
spy_roll.head(15)
# Out:
#                 Close
# Date
# 1993-01-29        NaN
# 1993-02-01        NaN
# 1993-02-02        NaN
# 1993-02-03        NaN
# 1993-02-04        NaN
# 1993-02-05        NaN
# 1993-02-08        NaN
# 1993-02-09        NaN
# 1993-02-10        NaN
# 1993-02-11  44.659375
# 1993-02-12  44.725000
# 1993-02-16  44.646875
# 1993-02-17  44.556250
# 1993-02-18  44.415625
# 1993-02-19  44.271875

# %%
spy.rolling(window=10).median()#takes the mid price
# Out:
#                  Close
# Date
# 1993-01-29         NaN
# 1993-02-01         NaN
# 1993-02-02         NaN
# 1993-02-03         NaN
# 1993-02-04         NaN
# ...                ...
# 2023-08-08  451.599991
# 2023-08-09  450.419998
# 2023-08-10  449.485001
# 2023-08-11  448.794998
# 2023-08-14  448.429993
#
# [7690 rows x 1 columns]

# %%
spy.rolling(window=10).max()
# Out:
#                  Close
# Date
# 1993-01-29         NaN
# 1993-02-01         NaN
# 1993-02-02         NaN
# 1993-02-03         NaN
# 1993-02-04         NaN
# ...                ...
# 2023-08-08  457.790009
# 2023-08-09  457.790009
# 2023-08-10  457.790009
# 2023-08-11  457.790009
# 2023-08-14  456.480011
#
# [7690 rows x 1 columns]

# %%
spy["SMA50"]=spy.rolling(window=50,min_periods=50).mean()
spy.head(52)
# Out:
#                Close     SMA50
# Date
# 1993-01-29  43.93750       NaN
# 1993-02-01  44.25000       NaN
# 1993-02-02  44.34375       NaN
# 1993-02-03  44.81250       NaN
# 1993-02-04  45.00000       NaN
# 1993-02-05  44.96875       NaN
# 1993-02-08  44.96875       NaN
# 1993-02-09  44.65625       NaN
# 1993-02-10  44.71875       NaN
# 1993-02-11  44.93750       NaN
# 1993-02-12  44.59375       NaN
# 1993-02-16  43.46875       NaN
# 1993-02-17  43.43750       NaN
# 1993-02-18  43.40625       NaN
# 1993-02-19  43.56250       NaN
# 1993-02-22  43.71875       NaN
# 1993-02-23  43.68750       NaN
# 1993-02-24  44.25000       NaN
# 1993-02-25  44.34375       NaN
# 1993-02-26  44.40625       NaN
# 1993-03-01  44.28125       NaN
# 1993-03-02  44.93750       NaN
# 1993-03-03  45.12500       NaN
# 1993-03-04  44.87500       NaN
# 1993-03-05  44.75000       NaN
# 1993-03-08  45.75000       NaN
# 1993-03-09  45.59375       NaN
# 1993-03-10  45.68750       NaN
# 1993-03-11  45.56250       NaN
# ...

# %%
spy.plot(figsize=(12,8), fontsize=15)
plt.legend(loc="upper left", fontsize=15)
plt.show()

# %%
spy["SMA200"]=spy.Close.rolling(window=200, min_periods=200).mean()
spy.plot(figsize=(12,8), fontsize=15)
plt.legend(loc="upper left", fontsize=15)
plt.show()

# %%
spy["Day"]=spy.index.day_name()#to mention the name
spy
# Out:
#                  Close       SMA50     SMA200        Day
# Date
# 1993-01-29   43.937500         NaN        NaN     Friday
# 1993-02-01   44.250000         NaN        NaN     Monday
# 1993-02-02   44.343750         NaN        NaN    Tuesday
# 1993-02-03   44.812500         NaN        NaN  Wednesday
# 1993-02-04   45.000000         NaN        NaN   Thursday
# ...                ...         ...        ...        ...
# 2023-08-08  448.750000  441.124000  409.49990    Tuesday
# 2023-08-09  445.750000  441.638600  409.90160  Wednesday
# 2023-08-10  445.910004  442.153201  410.25970   Thursday
# 2023-08-11  445.649994  442.709200  410.59360     Friday
# 2023-08-14  448.109985  443.235000  410.90955     Monday
#
# [7690 rows x 4 columns]

# %%
spy["Quarter"]=spy.index.quarter
spy
# Out:
#                  Close       SMA50     SMA200        Day  Quarter
# Date
# 1993-01-29   43.937500         NaN        NaN     Friday        1
# 1993-02-01   44.250000         NaN        NaN     Monday        1
# 1993-02-02   44.343750         NaN        NaN    Tuesday        1
# 1993-02-03   44.812500         NaN        NaN  Wednesday        1
# 1993-02-04   45.000000         NaN        NaN   Thursday        1
# ...                ...         ...        ...        ...      ...
# 2023-08-08  448.750000  441.124000  409.49990    Tuesday        3
# 2023-08-09  445.750000  441.638600  409.90160  Wednesday        3
# 2023-08-10  445.910004  442.153201  410.25970   Thursday        3
# 2023-08-11  445.649994  442.709200  410.59360     Friday        3
# 2023-08-14  448.109985  443.235000  410.90955     Monday        3
#
# [7690 rows x 5 columns]

# %%
SPY = yf.download("SPY")
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
spy=SPY.Close.to_frame()

# %%
spy
# Out:
#                  Close
# Date
# 1993-01-29   43.937500
# 1993-02-01   44.250000
# 1993-02-02   44.343750
# 1993-02-03   44.812500
# 1993-02-04   45.000000
# ...                ...
# 2023-08-10  445.910004
# 2023-08-11  445.649994
# 2023-08-14  448.109985
# 2023-08-15  442.890015
# 2023-08-16  439.640015
#
# [7692 rows x 1 columns]

# %%
all_days=pd.date_range(start="2010-12-31", end="2020-01-01" , freq="D")
all_days
# Out:
# DatetimeIndex(['2010-12-31', '2011-01-01', '2011-01-02', '2011-01-03',
#                '2011-01-04', '2011-01-05', '2011-01-06', '2011-01-07',
#                '2011-01-08', '2011-01-09',
#                ...
#                '2019-12-23', '2019-12-24', '2019-12-25', '2019-12-26',
#                '2019-12-27', '2019-12-28', '2019-12-29', '2019-12-30',
#                '2019-12-31', '2020-01-01'],
#               dtype='datetime64[ns]', length=3289, freq='D')

# %%
spy
# Out:
#                  Close
# Date
# 1993-01-29   43.937500
# 1993-02-01   44.250000
# 1993-02-02   44.343750
# 1993-02-03   44.812500
# 1993-02-04   45.000000
# ...                ...
# 2023-08-10  445.910004
# 2023-08-11  445.649994
# 2023-08-14  448.109985
# 2023-08-15  442.890015
# 2023-08-16  439.640015
#
# [7692 rows x 1 columns]

# %%
spy=spy.reindex(all_days)

# %%
spy
# Out:
#                  Close
# 2010-12-31  125.750000
# 2011-01-01         NaN
# 2011-01-02         NaN
# 2011-01-03  127.050003
# 2011-01-04  126.980003
# ...                ...
# 2019-12-28         NaN
# 2019-12-29         NaN
# 2019-12-30  321.079987
# 2019-12-31  321.859985
# 2020-01-01         NaN
#
# [3289 rows x 1 columns]

# %%
#to replace nan #we do forward fill or backward fill to get over this
#it prints the same thing as previous cell 
spy.fillna(method="ffill")
# Out:
#                  Close
# 2010-12-31  125.750000
# 2011-01-01  125.750000
# 2011-01-02  125.750000
# 2011-01-03  127.050003
# 2011-01-04  126.980003
# ...                ...
# 2019-12-28  322.859985
# 2019-12-29  322.859985
# 2019-12-30  321.079987
# 2019-12-31  321.859985
# 2020-01-01  321.859985
#
# [3289 rows x 1 columns]

# %%
spy.fillna(method="bfill")#backward fill takes next value
# Out:
#                  Close
# 2010-12-31  125.750000
# 2011-01-01  127.050003
# 2011-01-02  127.050003
# 2011-01-03  127.050003
# 2011-01-04  126.980003
# ...                ...
# 2019-12-28  321.079987
# 2019-12-29  321.079987
# 2019-12-30  321.079987
# 2019-12-31  321.859985
# 2020-01-01         NaN
#
# [3289 rows x 1 columns]

# %%
SPY = yf.download("SPY", interval="1wk")
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
SPY
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 1993-01-25   43.968750   43.968750   43.750000   43.937500   25.029369
# 1993-02-01   43.968750   45.093750   43.968750   44.968750   25.616829
# 1993-02-08   44.968750   45.125000   44.531250   44.593750   25.403217
# 1993-02-15   44.468750   44.468750   42.812500   43.562500   24.815756
# 1993-02-22   43.687500   44.437500   43.468750   44.406250   25.296408
# ...                ...         ...         ...         ...         ...
# 2023-07-17  449.130005  456.429993  449.079987  452.179993  452.179993
# 2023-07-24  453.369995  459.440002  451.549988  456.920013  456.920013
# 2023-07-31  457.410004  458.160004  446.269989  446.809998  446.809998
# 2023-08-07  448.709991  451.700012  443.350006  445.649994  445.649994
# 2023-08-14  444.700012  448.109985  439.529999  439.640015  439.640015
#
#                Volume
# Date
# 1993-01-25    1003200
# 1993-02-01    2234800
# 1993-02-08    1159800
# ...

# %% [markdown]
# # Cummulative Returns and Drawdowns

# %%
apple = yf.download("AAPL")
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
apple = apple.Close.to_frame()

# %%
apple
# Out:
#                  Close
# Date
# 1980-12-12    0.128348
# 1980-12-15    0.121652
# 1980-12-16    0.112723
# 1980-12-17    0.115513
# 1980-12-18    0.118862
# ...                ...
# 2023-08-10  177.970001
# 2023-08-11  177.789993
# 2023-08-14  179.460007
# 2023-08-15  177.449997
# 2023-08-16  176.570007
#
# [10759 rows x 1 columns]

# %%
apple["d_returns"]=np.log(apple.div(apple.shift(1)))

# %%
apple
# Out:
#                  Close  d_returns
# Date
# 1980-12-12    0.128348        NaN
# 1980-12-15    0.121652  -0.053581
# 1980-12-16    0.112723  -0.076231
# 1980-12-17    0.115513   0.024450
# 1980-12-18    0.118862   0.028580
# ...                ...        ...
# 2023-08-10  177.970001  -0.001235
# 2023-08-11  177.789993  -0.001012
# 2023-08-14  179.460007   0.009349
# 2023-08-15  177.449997  -0.011264
# 2023-08-16  176.570007  -0.004971
#
# [10759 rows x 2 columns]

# %%
apple.dropna(inplace=True)
apple
# Out:
#                  Close  d_returns
# Date
# 1980-12-15    0.121652  -0.053581
# 1980-12-16    0.112723  -0.076231
# 1980-12-17    0.115513   0.024450
# 1980-12-18    0.118862   0.028580
# 1980-12-19    0.126116   0.059239
# ...                ...        ...
# 2023-08-10  177.970001  -0.001235
# 2023-08-11  177.789993  -0.001012
# 2023-08-14  179.460007   0.009349
# 2023-08-15  177.449997  -0.011264
# 2023-08-16  176.570007  -0.004971
#
# [10758 rows x 2 columns]

# %%
apple.d_returns.sum()
# Out:
# 7.226727449315009

# %%
#now this line of code tells what you wouldve got if you wouldve
#invested 1 dollar in apple's stock on 1980-12-15
np.exp(apple.d_returns.sum())
# Out:
# 1375.7130387373638

# %%
apple["cummreturns"]=apple.d_returns.cumsum().apply(np.exp)
#cummulative returns

# %%
apple
# Out:
#                  Close  d_returns  cummreturns
# Date
# 1980-12-15    0.121652  -0.053581     0.947829
# 1980-12-16    0.112723  -0.076231     0.878261
# 1980-12-17    0.115513   0.024450     0.899998
# 1980-12-18    0.118862   0.028580     0.926092
# 1980-12-19    0.126116   0.059239     0.982610
# ...                ...        ...          ...
# 2023-08-10  177.970001  -0.001235  1386.620836
# 2023-08-11  177.789993  -0.001012  1385.218337
# 2023-08-14  179.460007   0.009349  1398.229942
# 2023-08-15  177.449997  -0.011264  1382.569318
# 2023-08-16  176.570007  -0.004971  1375.713039
#
# [10758 rows x 3 columns]

# %%
apple.cummreturns.plot(figsize=(12,8) ,title="Apple buy and hold", fontsize=(12))
plt.show()

# %%
#annual mean return and annual standard deviation 
apple.d_returns.mean()*252
# Out:
# 0.16928195921429467

# %%
apple.d_returns.std()*np.sqrt(252)
# Out:
# 0.45319941019090443

# %%
#cummalative maximum calculated for calculating drawbacks 
#we calculate peak and the valley 
#what is the maximum it went high 

apple["cummax"]=apple.cummreturns.cummax()

# %%
apple
# Out:
#                  Close  d_returns  cummreturns       cummax
# Date
# 1980-12-15    0.121652  -0.053581     0.947829     0.947829
# 1980-12-16    0.112723  -0.076231     0.878261     0.947829
# 1980-12-17    0.115513   0.024450     0.899998     0.947829
# 1980-12-18    0.118862   0.028580     0.926092     0.947829
# 1980-12-19    0.126116   0.059239     0.982610     0.982610
# ...                ...        ...          ...          ...
# 2023-08-10  177.970001  -0.001235  1386.620836  1530.604356
# 2023-08-11  177.789993  -0.001012  1385.218337  1530.604356
# 2023-08-14  179.460007   0.009349  1398.229942  1530.604356
# 2023-08-15  177.449997  -0.011264  1382.569318  1530.604356
# 2023-08-16  176.570007  -0.004971  1375.713039  1530.604356
#
# [10758 rows x 4 columns]

# %%
apple[["cummreturns","cummax"]].plot(figsize=(12,8) ,title="Apple buy and hold+cummax", fontsize=(12))
plt.show()

# %%
apple["drawdown"]=apple["cummax"]-apple["cummreturns"]

# %%
apple
# Out:
#                  Close  d_returns  cummreturns       cummax    drawdown
# Date
# 1980-12-15    0.121652  -0.053581     0.947829     0.947829    0.000000
# 1980-12-16    0.112723  -0.076231     0.878261     0.947829    0.069569
# 1980-12-17    0.115513   0.024450     0.899998     0.947829    0.047831
# 1980-12-18    0.118862   0.028580     0.926092     0.947829    0.021738
# 1980-12-19    0.126116   0.059239     0.982610     0.982610    0.000000
# ...                ...        ...          ...          ...         ...
# 2023-08-10  177.970001  -0.001235  1386.620836  1530.604356  143.983519
# 2023-08-11  177.789993  -0.001012  1385.218337  1530.604356  145.386018
# 2023-08-14  179.460007   0.009349  1398.229942  1530.604356  132.374413
# 2023-08-15  177.449997  -0.011264  1382.569318  1530.604356  148.035038
# 2023-08-16  176.570007  -0.004971  1375.713039  1530.604356  154.891317
#
# [10758 rows x 5 columns]

# %%
apple.drawdown.max()
# Out:
# 444.02718404402094

# %%
apple.drawdown.idxmax()
# Out:
# Timestamp('2023-01-05 00:00:00')

# %%
apple.loc[(apple.index =="2023-01-05")]
# Out:
#                  Close  d_returns  cummreturns       cummax    drawdown
# Date
# 2023-01-05  125.019997  -0.010661   974.070524  1418.097708  444.027184

# %%
apple.loc[(apple.index <="2023-01-05")]
# Out:
#                  Close  d_returns  cummreturns       cummax    drawdown
# Date
# 1980-12-15    0.121652  -0.053581     0.947829     0.947829    0.000000
# 1980-12-16    0.112723  -0.076231     0.878261     0.947829    0.069569
# 1980-12-17    0.115513   0.024450     0.899998     0.947829    0.047831
# 1980-12-18    0.118862   0.028580     0.926092     0.947829    0.021738
# 1980-12-19    0.126116   0.059239     0.982610     0.982610    0.000000
# ...                ...        ...          ...          ...         ...
# 2022-12-29  129.610001   0.027931  1009.832703  1418.097708  408.265004
# 2022-12-30  129.929993   0.002466  1012.325863  1418.097708  405.771845
# 2023-01-03  125.070000  -0.038122   974.460113  1418.097708  443.637594
# 2023-01-04  126.360001   0.010261   984.510920  1418.097708  433.586787
# 2023-01-05  125.019997  -0.010661   974.070524  1418.097708  444.027184
#
# [10605 rows x 5 columns]

# %%
apple["drawdown%"]=(apple["cummax"]-apple["cummreturns"])/apple["cummax"]

# %%
apple
# Out:
#                  Close  d_returns  cummreturns       cummax    drawdown  \
# Date
# 1980-12-15    0.121652  -0.053581     0.947829     0.947829    0.000000
# 1980-12-16    0.112723  -0.076231     0.878261     0.947829    0.069569
# 1980-12-17    0.115513   0.024450     0.899998     0.947829    0.047831
# 1980-12-18    0.118862   0.028580     0.926092     0.947829    0.021738
# 1980-12-19    0.126116   0.059239     0.982610     0.982610    0.000000
# ...                ...        ...          ...          ...         ...
# 2023-08-10  177.970001  -0.001235  1386.620836  1530.604356  143.983519
# 2023-08-11  177.789993  -0.001012  1385.218337  1530.604356  145.386018
# 2023-08-14  179.460007   0.009349  1398.229942  1530.604356  132.374413
# 2023-08-15  177.449997  -0.011264  1382.569318  1530.604356  148.035038
# 2023-08-16  176.570007  -0.004971  1375.713039  1530.604356  154.891317
#
#             drawdown%
# Date
# 1980-12-15   0.000000
# 1980-12-16   0.073398
# ...

# %%
apple["drawdown%"].max()
# Out:
# 0.82216567924191

# %%
apple["drawdown%"].idxmax()
# Out:
# Timestamp('1997-12-23 00:00:00')

# %%
apple.loc[(apple.index <="1997-12-23")]
# Out:
#                Close  d_returns  cummreturns    cummax  drawdown  drawdown%
# Date
# 1980-12-15  0.121652  -0.053581     0.947829  0.947829  0.000000   0.000000
# 1980-12-16  0.112723  -0.076231     0.878261  0.947829  0.069569   0.073398
# 1980-12-17  0.115513   0.024450     0.899998  0.947829  0.047831   0.050464
# 1980-12-18  0.118862   0.028580     0.926092  0.947829  0.021738   0.022934
# 1980-12-19  0.126116   0.059239     0.982610  0.982610  0.000000   0.000000
# ...              ...        ...          ...       ...       ...        ...
# 1997-12-17  0.124442  -0.026549     0.969567  5.060882  4.091315   0.808419
# 1997-12-18  0.123326  -0.009008     0.960872  5.060882  4.100010   0.810137
# 1997-12-19  0.122210  -0.009090     0.952177  5.060882  4.108705   0.811856
# 1997-12-22  0.118862  -0.027778     0.926092  5.060882  4.134790   0.817010
# 1997-12-23  0.115513  -0.028580     0.899998  5.060882  4.160883   0.822166
#
# [4306 rows x 6 columns]

# %% [markdown]
# these are the things that you normally check like standard deviation and thre returns and when did the stock peak and when did it fall down, it has the highest standard deviation apple's stock

# %% [markdown]
# # Creating better strategies SMA
# Simple Moving Average (SMA): Trading Strategy
# A simple Moving Average is the average market price of a security over a specified period. It is referred to as the 'moving' average since it is plotted on a chart bar by bar and forms a line that moves along the chart as the average price changes.

# %%
data = apple.Close.loc[(apple.index >="1991-01-01")]

# %%
data = data.to_frame()

# %%
data
# Out:
#                  Close
# Date
# 1991-01-02    0.388393
# 1991-01-03    0.383929
# 1991-01-04    0.386161
# 1991-01-07    0.386161
# 1991-01-08    0.386161
# ...                ...
# 2023-08-10  177.970001
# 2023-08-11  177.789993
# 2023-08-14  179.460007
# 2023-08-15  177.449997
# 2023-08-16  176.570007
#
# [8218 rows x 1 columns]

# %%
sma_s = 50 
sma_l = 100

# %%
data["sma_s"]=data.Close.rolling(sma_s).mean()
data["sma_l"]=data.Close.rolling(sma_l).mean()

# %%
data
# Out:
#                  Close       sma_s     sma_l
# Date
# 1991-01-02    0.388393         NaN       NaN
# 1991-01-03    0.383929         NaN       NaN
# 1991-01-04    0.386161         NaN       NaN
# 1991-01-07    0.386161         NaN       NaN
# 1991-01-08    0.386161         NaN       NaN
# ...                ...         ...       ...
# 2023-08-10  177.970001  187.431801  177.2556
# 2023-08-11  177.789993  187.442600  177.4595
# 2023-08-14  179.460007  187.430001  177.6613
# 2023-08-15  177.449997  187.360001  177.8575
# 2023-08-16  176.570007  187.299801  178.0339
#
# [8218 rows x 3 columns]

# %%
data.plot(figsize=(12,8), title="APPLE - SMA{} | SMA{}".format(sma_s,sma_l), fontsize=12)
# Out:
# <Axes: title={'center': 'APPLE - SMA50 | SMA100'}, xlabel='Date'>

# %%
data.loc["2016"].plot(figsize=(12,8), title="APPLE - SMA{} | SMA{}".format(sma_s,sma_l), fontsize=12)
# Out:
# <Axes: title={'center': 'APPLE - SMA50 | SMA100'}, xlabel='Date'>

# %%
data.dropna(inplace=True)

# %%
data
# Out:
#                  Close       sma_s       sma_l
# Date
# 1991-05-23    0.402902    0.534420    0.513326
# 1991-05-24    0.409598    0.530960    0.513538
# 1991-05-28    0.410714    0.527344    0.513806
# 1991-05-29    0.419643    0.523638    0.514141
# 1991-05-30    0.425223    0.519732    0.514531
# ...                ...         ...         ...
# 2023-08-10  177.970001  187.431801  177.255600
# 2023-08-11  177.789993  187.442600  177.459500
# 2023-08-14  179.460007  187.430001  177.661300
# 2023-08-15  177.449997  187.360001  177.857500
# 2023-08-16  176.570007  187.299801  178.033900
#
# [8119 rows x 3 columns]

# %%
data["position"]=np.where(data["sma_s"]>data["sma_l"],1,-1)

# %%
data
# Out:
#                  Close       sma_s       sma_l  position
# Date
# 1991-05-23    0.402902    0.534420    0.513326         1
# 1991-05-24    0.409598    0.530960    0.513538         1
# 1991-05-28    0.410714    0.527344    0.513806         1
# 1991-05-29    0.419643    0.523638    0.514141         1
# 1991-05-30    0.425223    0.519732    0.514531         1
# ...                ...         ...         ...       ...
# 2023-08-10  177.970001  187.431801  177.255600         1
# 2023-08-11  177.789993  187.442600  177.459500         1
# 2023-08-14  179.460007  187.430001  177.661300         1
# 2023-08-15  177.449997  187.360001  177.857500         1
# 2023-08-16  176.570007  187.299801  178.033900         1
#
# [8119 rows x 4 columns]

# %%
data.loc["2016",["sma_s","sma_l","position"]].plot(figsize=(12,8), title="APPLE - SMA{} | SMA{}".format(sma_s,sma_l), fontsize=12, secondary_y="position")
# Out:
# <Axes: title={'center': 'APPLE - SMA50 | SMA100'}, xlabel='Date'>

# %%
data["returnsb&h"]=np.log(data.Close.div(data.Close.shift(1)))
data["strategy"]=data["returnsb&h"]*data.position.shift(1)

# %%
data
# Out:
#                  Close       sma_s       sma_l  position  returnsb&h  strategy
# Date
# 1991-05-23    0.402902    0.534420    0.513326         1         NaN       NaN
# 1991-05-24    0.409598    0.530960    0.513538         1    0.016483  0.016483
# 1991-05-28    0.410714    0.527344    0.513806         1    0.002721  0.002721
# 1991-05-29    0.419643    0.523638    0.514141         1    0.021507  0.021507
# 1991-05-30    0.425223    0.519732    0.514531         1    0.013209  0.013209
# ...                ...         ...         ...       ...         ...       ...
# 2023-08-10  177.970001  187.431801  177.255600         1   -0.001235 -0.001235
# 2023-08-11  177.789993  187.442600  177.459500         1   -0.001012 -0.001012
# 2023-08-14  179.460007  187.430001  177.661300         1    0.009349  0.009349
# 2023-08-15  177.449997  187.360001  177.857500         1   -0.011264 -0.011264
# 2023-08-16  176.570007  187.299801  178.033900         1   -0.004971 -0.004971
#
# ...

# %%
data.dropna(inplace=True)

# %%
data[["returnsb&h", "strategy"]].sum()
# Out:
# returnsb&h    6.082779
# strategy      2.121020
# dtype: float64

# %%
data[["returnsb&h", "strategy"]].sum().apply(np.exp)#what one dollar investment would be
# Out:
# returnsb&h    438.245539
# strategy        8.339639
# dtype: float64

# %%
data[["returnsb&h", "strategy"]].std()*np.sqrt(252)#annual standard deviation
# Out:
# returnsb&h    0.436978
# strategy      0.437120
# dtype: float64

# %%
data.Close.plot(figsize=(12,8))
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# # Strategy adjusted with long bias

# %%
data["position2"]=np.where(data["sma_s"]>data["sma_l"],1,0)

# %%
data["strategy2"]=data["returnsb&h"]*data.position2.shift(1)

# %%
data
# Out:
#                  Close       sma_s       sma_l  position  returnsb&h  \
# Date
# 1991-05-24    0.409598    0.530960    0.513538         1    0.016483
# 1991-05-28    0.410714    0.527344    0.513806         1    0.002721
# 1991-05-29    0.419643    0.523638    0.514141         1    0.021507
# 1991-05-30    0.425223    0.519732    0.514531         1    0.013209
# 1991-05-31    0.419643    0.516027    0.514866         1   -0.013209
# ...                ...         ...         ...       ...         ...
# 2023-08-10  177.970001  187.431801  177.255600         1   -0.001235
# 2023-08-11  177.789993  187.442600  177.459500         1   -0.001012
# 2023-08-14  179.460007  187.430001  177.661300         1    0.009349
# 2023-08-15  177.449997  187.360001  177.857500         1   -0.011264
# 2023-08-16  176.570007  187.299801  178.033900         1   -0.004971
#
#             strategy  position2  strategy2
# Date
# 1991-05-24  0.016483          1        NaN
# ...

# %%
data.dropna(inplace=True)

# %%
data
# Out:
#                  Close       sma_s       sma_l  position  returnsb&h  \
# Date
# 1991-05-28    0.410714    0.527344    0.513806         1    0.002721
# 1991-05-29    0.419643    0.523638    0.514141         1    0.021507
# 1991-05-30    0.425223    0.519732    0.514531         1    0.013209
# 1991-05-31    0.419643    0.516027    0.514866         1   -0.013209
# 1991-06-03    0.439732    0.513259    0.515223         0    0.046761
# ...                ...         ...         ...       ...         ...
# 2023-08-10  177.970001  187.431801  177.255600         1   -0.001235
# 2023-08-11  177.789993  187.442600  177.459500         1   -0.001012
# 2023-08-14  179.460007  187.430001  177.661300         1    0.009349
# 2023-08-15  177.449997  187.360001  177.857500         1   -0.011264
# 2023-08-16  176.570007  187.299801  178.033900         1   -0.004971
#
#             strategy  position2  strategy2
# Date
# 1991-05-28  0.002721          1   0.002721
# ...

# %%
data[["returnsb&h", "strategy2"]].sum()
# Out:
# returnsb&h    6.066297
# strategy2     4.085417
# dtype: float64

# %%
data[["returnsb&h", "strategy2"]].sum().apply(np.exp)#one. dollar
# Out:
# returnsb&h    431.081232
# strategy2      59.466720
# dtype: float64

# %%
data[["returnsb&h", "strategy2"]].std()*np.sqrt(252)#annual standard deviation
# Out:
# returnsb&h    0.436996
# strategy2     0.337801
# dtype: float64

# %% [markdown]
# strategy 2 is better than strategy one

# %%
data[["strategy","strategy2"]].std()*np.sqrt(252)
# Out:
# strategy     0.437138
# strategy2    0.337801
# dtype: float64

# %% [markdown]
# # Creating our first function

# %%
def test_strategy(stock, start, end, SMA):
    df=yf.download(stock,start=start,end=end)
    data=df.Close.to_frame()
    data["returns"]=np.log(data.Close.div(data.Close.shift(1)))
    data["SMA_S"]=data.Close.rolling(int(SMA[0])).mean()
    data["SMA_L"]=data.Close.rolling(int(SMA[1])).mean()
    data.dropna(inplace=True)
    
    data["position"]=np.where(data["SMA_S"]>data["SMA_L"],1,-1)
    data["strategy"]=data["returns"]*data.position.shift(1)
    data.dropna(inplace=True)
    ret=np.exp(data["strategy"].sum())
    std=data["strategy"].std()*np.sqrt(252)
    
    return ret,std

# %%
test_strategy("MSFT", "2000-01-01", "2023-12-08", (50,200))
# Out:
# [*********************100%***********************]  1 of 1 completed
# (0.8642340660487691, 0.2984812045388265)

# %%
test_strategy("AAPL", "2000-01-01", "2023-12-08", (50,200))
# Out:
# [*********************100%***********************]  1 of 1 completed
# (27.904957215734527, 0.3639246078678327)

# %%
test_strategy("TSLA", "2000-01-01", "2023-12-08", (50,200))
# Out:
# [*********************100%***********************]  1 of 1 completed
# (7.465142959691307, 0.5628962976942397)

# %%
test_strategy("SPY", "2000-01-01", "2023-12-08", (50,200))
# Out:
# [*********************100%***********************]  1 of 1 completed
# (4.480084103768429, 0.19634481371610069)

# %% [markdown]
# # Creating our first Class

# %%
class SMABacktester():
    def __init__(self, symbol, SMA_S, SMA_L, start, end):
        self.symbol=symbol
        self.SMA_S=SMA_S
        self.SMA_L=SMA_L
        self.start=start
        self.end =end
        self.results=None
        self.get_data()
        
    def get_data(self):
        df=yf.download(self.symbol, start=self.start, end=self.end)
        data=df.Close.to_frame()
        data["returns"]=np.log(data.Close.div(data.Close.shift(1)))
        data["SMA_S"]=data.Close.rolling(self.SMA_S).mean()
        data["SMA_L"]=data.Close.rolling(self.SMA_L).mean()
        data.dropna(inplace=True)
        self.data2=data
        
        return data
    
    def test_results(self):
        data=self.data2.copy().dropna()
        data["position"]=np.where(data["SMA_S"]>data["SMA_L"],1,-1)
        data["strategy"]=data["returns"]*data.position.shift(1)
        data.dropna(inplace=True)
        data["returnsbh"]=data["returns"].cumsum().apply(np.exp)
        data["returnsstrategy"]=data["strategy"].cumsum().apply(np.exp)
        perf=data["returnsstrategy"].iloc[-1]
        outperf=perf-data["returnsbh"].iloc[-1]
        self.results=data
        
        
        ret=np.exp(data["strategy"].sum())
        std=data["strategy"].std()*np.sqrt(252)
        
        return round(perf,6), round(outperf,6)
    
    def plot_results(self):
        if self.results is None:
            print("Run the test please")
        else:
            title="{}| SMA_S={} SMA_L{}".format(self.symbol, self.SMA_S, self.SMA_L)
            self.results[["returnsbh","returnsstrategy"]].plot(title=title, figsize=(12,8))

# %%
tester = SMABacktester("AAPL",1,200, "2000-01-01", "2020-01-01")
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
tester.test_results()
# Out:
# (239.027886, 47.814157)

# %%
tester.plot_results()
